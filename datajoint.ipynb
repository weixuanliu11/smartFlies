# %%
from plume.schema import *
# Out:
# [2023-12-11 18:15:58,460][INFO]: Connecting jq@dev0.uwcnc.net:3306
# [2023-12-11 18:15:58,466][INFO]: Connected jq@dev0.uwcnc.net:3306

# %%
TrainingConfig()
# Out:
# *training_conf algo     lr         eps       alpha     gamma     use_gae     gae_lambda     entropy_coef   value_loss_coe max_grad_norm  seed     cuda_determini num_processes  num_steps     ppo_epoch     num_mini_batch clip_param     log_interval   save_interval  no_cuda     use_proper_tim recurrent_poli use_linear_lr_ env_name     log_dir       save_dir       dynamic     eval_type     eval_episodes  eval_interval  weight_decay   rnn_type     hidden_size    betadist     stacking     masking     stride     dataset    num_env_st qvar       birthx     diff_max   diff_min   birthx_linear_ birthx_max     dryrun     curriculum     turnx     movex     auto_movex     auto_reward    loc_algo     time_algo     env_dt     outsuffix      walking     radiusx     diffusion_min  diffusion_max  r_shaping  wind_rel     action_feedbac squash_action  flipping     odor_scaling   stray_max     test_episodes  viz_episodes   model_fname    obs_noise     act_noise     cuda
# ...

# %%
TrainingResult.populate()
# Out:
# PPO Args ---> {'training_config_hash': '99a373e874d5aa2966c091a9aee19039', 'algo': 'ppo', 'lr': 0.0003, 'eps': 1e-05, 'alpha': 0.99, 'gamma': 0.99, 'use_gae': 1, 'gae_lambda': 0.95, 'entropy_coef': 0.005, 'value_loss_coef': 0.5, 'max_grad_norm': 0.5, 'seed': 2894, 'cuda_deterministic': 0, 'num_processes': 4, 'num_steps': 2048, 'ppo_epoch': 10, 'num_mini_batch': 4, 'clip_param': 0.2, 'log_interval': 1.0, 'save_interval': 100.0, 'no_cuda': 0, 'use_proper_time_limits': 0, 'recurrent_policy': 1, 'use_linear_lr_decay': 1, 'env_name': 'plume', 'log_dir': '/tmp/gym/', 'save_dir': './sw_dist_logstep_0.001/', 'dynamic': 0, 'eval_type': 'skip', 'eval_episodes': 20, 'eval_interval': None, 'weight_decay': 0.0001, 'rnn_type': 'VRNN', 'hidden_size': 64, 'betadist': 0, 'stacking': 0, 'masking': None, 'stride': 1, 'dataset': ['constantx5b5', 'noisy3x5b5'], 'num_env_steps': [1000000, 4000000], 'qvar': [2.0, 0.5], 'birthx': [0.3, 0.8], 'diff_max': [0.8, 0.8], 'diff_min': [0.7, 0.4], 'birthx_linear_tc_
# ...

# %%
TrainingResult()
# Out:
# *training_conf perf
# +------------+ +------+
# 99a373e874d5aa 0.0
#  (Total: 1)

# %%
dict_to_insert = {'algo': 'ppo',
 'lr': 0.0003,
 'eps': 1e-05,
 'alpha': 0.99,
 'gamma': 0.99,
 'use_gae': True,
 'gae_lambda': 0.95,
 'entropy_coef': 0.005,
 'value_loss_coef': 0.5,
 'max_grad_norm': 0.5,
 'seed': 2894,
 'cuda_deterministic': False,
 'num_processes': 4,
 'num_steps': 2048,
 'ppo_epoch': 10,
 'num_mini_batch': 4,
 'clip_param': 0.2,
 'log_interval': 1,
 'save_interval': 100,
 'no_cuda': False,
 'use_proper_time_limits': False,
 'recurrent_policy': True,
 'use_linear_lr_decay': True,
 'env_name': 'plume',
 'log_dir': '/tmp/gym/',
 'save_dir': './sw_dist_logstep_0.001/',
 'dynamic': False,
 'eval_type': 'skip',
 'eval_episodes': 20,
 'eval_interval': None,
 'weight_decay': 0.0001,
 'rnn_type': 'VRNN',
 'hidden_size': 64,
 'betadist': False,
 'stacking': 0,
 'masking': None,
 'stride': 1,
 'dataset': ['constantx5b5', 'noisy3x5b5'],
 'num_env_steps': [1000000, 4000000],
 'qvar': [2.0, 0.5],
 'birthx': [0.3, 0.8],
 'diff_max': [0.8, 0.8],
 'diff_min': [0.7, 0.4],
 'birthx_linear_tc_steps': 12,
 'birthx_max': 1.0,
 'dryrun': False,
 'curriculum': False,
 'turnx': 1.0,
 'movex': 1.0,
 'auto_movex': False,
 'auto_reward': False,
 'loc_algo': 'uniform',
 'time_algo': 'uniform',
 'env_dt': 0.04,
 'outsuffix': '20231204_VRNN_constantx5b5noisy3x5b5_stepoob_bx0.0010.1_t15000006000000_q2.00.5_dmx0.80.8_dmn0.70.4_h64_wd0.0001_n4_codeVRNN_seed289435',
 'walking': False,
 'radiusx': 1.0,
 'diffusion_min': 1.0,
 'diffusion_max': 1.0,
 'r_shaping': ['step', 'oob'],
 'wind_rel': True,
 'action_feedback': False,
 'squash_action': True,
 'flipping': True,
 'odor_scaling': True,
 'stray_max': 2.0,
 'test_episodes': 50,
 'viz_episodes': 10,
 'model_fname': '',
 'obs_noise': 0.0,
 'act_noise': 0.0,
 'cuda': True
 }

# %%
TrainingConfig.insert1(dict_to_insert)

# %%
 'dataset': ['constantx5b5', 'noisy3x5b5'],
 'num_env_steps': [1000000, 4000000],
 'qvar': [2.0, 0.5],
 'birthx': [0.3, 0.8],
 'diff_max': [0.8, 0.8],
 'diff_min': [0.7, 0.4],
 'outsuffix': '20231204_VRNN_constantx5b5noisy3x5b5_stepoob_bx0.0010.1_t15000006000000_q2.00.5_dmx0.80.8_dmn0.70.4_h64_wd0.0001_n4_codeVRNN_seed289435',
 'birthx_linear_tc_steps': 12,
# Out:
# *training_conf algo     lr         eps       alpha     gamma     use_gae     gae_lambda     entropy_coef   value_loss_coe max_grad_norm  seed     cuda_determini num_processes  num_steps     ppo_epoch     num_mini_batch clip_param     log_interval   save_interval  no_cuda     use_proper_tim recurrent_poli use_linear_lr_ env_name     log_dir       save_dir       dynamic     eval_type     eval_episodes  eval_interval  weight_decay   rnn_type     hidden_size    betadist     stacking     masking     stride     dataset    num_env_st qvar       birthx     diff_max   diff_min   birthx_linear_ birthx_max     dryrun     curriculum     turnx     movex     auto_movex     auto_reward    loc_algo     time_algo     env_dt     outsuffix      walking     radiusx     diffusion_min  diffusion_max  r_shaping  wind_rel     action_feedbac squash_action  flipping     odor_scaling   stray_max     test_episodes  viz_episodes   model_fname    obs_noise     act_noise     cuda
# ...

# %%
TrainingConfig & 'lr < 1'
# Out:
# *training_conf algo     lr         eps       alpha     gamma     use_gae     gae_lambda     entropy_coef   value_loss_coe max_grad_norm  seed     cuda_determini num_processes  num_steps     ppo_epoch     num_mini_batch clip_param     log_interval   save_interval  no_cuda     use_proper_tim recurrent_poli use_linear_lr_ env_name     log_dir       save_dir       dynamic     eval_type     eval_episodes  eval_interval  weight_decay   rnn_type     hidden_size    betadist     stacking     masking     stride     dataset    num_env_st qvar       birthx     diff_max   diff_min   birthx_linear_ birthx_max     dryrun     curriculum     turnx     movex     auto_movex     auto_reward    loc_algo     time_algo     env_dt     outsuffix      walking     radiusx     diffusion_min  diffusion_max  r_shaping  wind_rel     action_feedbac squash_action  flipping     odor_scaling   stray_max     test_episodes  viz_episodes   model_fname    obs_noise     act_noise     cuda
# ...
