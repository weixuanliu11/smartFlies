# %%
# read in the credentials as environment variables
import sys
import os
cwd = os.getcwd()
if cwd.__contains__('src'):
    env_vars = !cat /src/.env
elif cwd.startswith('/data/users/jqhu'):
    env_vars = !cat /data/users/jqhu/work/tamagotchi/smartFlies/.env
    sys.path.append('/data/users/jqhu/work/tamagotchi/smartFlies')
else:
    env_vars = !cat /gscratch/walkerlab/jqhu/smartFlies/tamagotchi/.env

for var in env_vars:
    key, value = var.split('=')
    os.environ[key] = value

from schemas.schema_v4 import *
# Out:
# 2025-04-07 17:35:16.130379: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744047316.170132   90479 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744047316.182691   90479 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-07 17:35:16.262046: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2025-04-07 17:35:18,834][INFO]: Connecting jq@dev0.uwcnc.net:3306
# [2025-04-07 17:35:18,844][INFO]: Connected jq@dev0.uwcnc.net:3306

# %%
schema.jobs
# (schema.jobs & 'host="3487181d157e"').delete()
# (schema.jobs & 'key_hash="c66f480230103ca9123cecd6b3f8df96"').delete()
# (schema.jobs & 'status="error"' & 'key_hash="0bb9a16627e73f4077ef6a5c2fbc67b9"').delete()
# (schema.jobs & 'status="error"' & 'key_hash="22877960269526f63370b8c034837d9c"').fetch()

# schema.jobs.delete()
# Out:
# *table_name    *key_hash      status     key        error_message  error_stac user           host           pid     connection_id  timestamp
# +------------+ +------------+ +--------+ +--------+ +------------+ +--------+ +------------+ +------------+ +-----+ +------------+ +------------+
# __training_res 1f65538675f812 error      =BLOB=     MlflowExceptio =BLOB=     jq@128.95.81.1 3487181d157e   103     4008           2024-09-25 17:
# __training_res 708745d318ca00 error      =BLOB=     MlflowExceptio =BLOB=     jq@128.95.81.1 3487181d157e   102     4008           2024-09-25 17:
# __training_res ba0c80ee557474 error      =BLOB=     MlflowExceptio =BLOB=     jq@128.95.81.1 3487181d157e   104     4008           2024-09-25 17:
#  (Total: 3)

# %%
TrainingConfig()
# for hash in ['c97448325b629989b2d82e8f2f325c55', '45513dd8ac9d9cdbb3a34f957436f7af', 'dee781bba1737b60f0e9b494f6acfdfc']:
#     print((TrainingConfig() & f'training_config_hash="{hash}"').fetch()[['save_dir', 'seed']])
# (TrainingConfig() & 'training_config_hash="d1cc1b54c140f764025f8fc169a34456"').fetch()[['save_dir', 'seed']]
# (TrainingConfig() & 'save_dir="/src/data/wind_sensing/apparent_wind_visual_feedback/sw_dist_logstep_wind_0.001_groundV_appW_debug_obs_noise_0.1/"')
# Out:
# *training_conf algo     lr         eps       alpha     gamma     use_gae     gae_lambda     entropy_coef   value_loss_coe max_grad_norm  seed      cuda_determini num_processes  num_steps     ppo_epoch     num_mini_batch clip_param     log_interval   save_interval  no_cuda     use_proper_tim recurrent_poli use_linear_lr_ env_name     log_dir       save_dir       outsuffix      dynamic     eval_type     eval_episodes  eval_interval  weight_decay   rnn_type     hidden_size    betadist     stacking     masking     stride     dataset    num_env_steps  qvar       birthx     diff_max   diff_min   birthx_linear_ birthx_max     dryrun     curriculum     turnx     movex     auto_movex     auto_reward    loc_algo     time_algo     env_dt     walking     radiusx     diffusion_min  diffusion_max  r_shaping  wind_rel     action_feedbac squash_action  flipping     odor_scaling   stray_max     test_episodes  viz_episodes   model_fname    obs_noise     act_noise     cuda     apparent_wind  apparent_wind_ visual_feedbac if_vec_norm    if_train_actor
# +------------+ +------+ +--------+ +-------+ +-------+ +-------+ +---------+ +------------+ +------------+ +------------+ +------------+ +-------+ +------------+ +------------+ +-----------+ +-----------+ +------------+ +------------+ +------------+ +------------+ +---------+ +------------+ +------------+ +------------+ +----------+ +-----------+ +------------+ +------------+ +---------+ +-----------+ +------------+ +------------+ +------------+ +----------+ +------------+ +----------+ +----------+ +---------+ +--------+ +--------+ +------------+ +--------+ +--------+ +--------+ +--------+ +------------+ +------------+ +--------+ +------------+ +-------+ +-------+ +------------+ +------------+ +----------+ +-----------+ +--------+ +---------+ +---------+ +------------+ +------------+ +--------+ +----------+ +------------+ +------------+ +----------+ +------------+ +-----------+ +------------+ +------------+ +------------+ +-----------+ +-----------+ +------+ +------------+ +------------+ +------------+ +------------+ +------------+
# 001935298c849c ppo      0.0003     1e-05     0.99      0.99      1           0.95           0.005          0.5            0.5            30698     0              4              2048          10            4              0.2            1.0            100.0          0           0              1              1              plume        /tmp/gym/     /src/data/wind 30698_00193529 0           skip          20             None           0.0001         VRNN         64             0            0            None        1          =BLOB=     10000000       =BLOB=     0.001      =BLOB=     =BLOB=     7              1.0            0          0              1.0       1.0       0              0              uniform      uniform       0.04       0           1.0         1.0            1.0            =BLOB=     1            0              1              1            1              2.0           50             10                            0.0           0.0           1        1              0              1              1              1
# 00679d6cb443c1 ppo      0.0003     1e-05     0.99      0.99      1           0.95           0.005          0.5            0.5            1312      0              4              2048          10            4              0.2            1.0            100.0          0           0              1              1              plume        /tmp/gym/     /src/data/wind 1312_00679d6cb 0           skip          20             None           0.0001         VRNN         64             0            0            None        1          =BLOB=     10000000       =BLOB=     0.01       =BLOB=     =BLOB=     7              1.0            0          0              1.0       1.0       0              0              uniform      uniform       0.04       0           1.0         1.0            1.0            =BLOB=     1            0              1              1            1              2.0           50             10                            0.0           0.0           1        1              0              1              1              1
# 0c7a79ccdebe66 ppo      0.0003     1e-05     0.99      0.99      1           0.95           0.005          0.5            0.5            8250      0              4              2048          10            4              0.2            1.0            100.0          0           0              1              1              plume        /tmp/gym/     /src/data/wind 8250_0c7a79ccd 0           skip          20             None           0.0001         VRNN         64             0            0            None        1          =BLOB=     10000000       =BLOB=     0.01       =BLOB=     =BLOB=     7              1.0            0          0              1.0       1.0       0              0              uniform      uniform       0.04       0           1.0         1.0            1.0            =BLOB=     1            0              1              1            1              2.0           50             10                            0.0           0.0           1        1              0              1              1              1
# 0d59ae1f145ef9 ppo      0.0003     1e-05     0.99      0.99      1           0.95           0.005          0.5            0.5            24371     0              4              2048          10            4              0.2            1.0            100.0          0           0              1              1              plume        /tmp/gym/     /src/data/wind 24371_0d59ae1f 0           skip          20             None           0.0001         VRNN         64             0            0            None        1          =BLOB=     10000000       =BLOB=     0.01       =BLOB=     =BLOB=     7              1.0            0          0              1.0       1.0       0              0              uniform      uniform       0.04       0           1.0         1.0            1.0            =BLOB=     1            0              1              1            1              2.0           50             10                            0.0           0.0           1        1              0              1              1              1
# 0d71853abf0059 ppo      0.0003     1e-05     0.99      0.99      1           0.95           0.005          0.5            0.5            25256     0              4              2048          10            4              0.2            1.0            100.0          0           0              1              1              plume        /tmp/gym/     /src/data/wind 25256_0d71853a 0           skip          20             None           0.0001         VRNN         64             0            0            None        1          =BLOB=     10000000       =BLOB=     0.001      =BLOB=     =BLOB=     7              1.0            0          0              1.0       1.0       0              0              uniform      uniform       0.04       0           1.0         1.0            1.0            =BLOB=     1            0              1              1            1              2.0           50             10                            0.0           0.0           1        1              0              1              0              0
# 0daaa07e31a5b3 ppo      0.0003     1e-05     0.99      0.99      1           0.95           0.005          0.5            0.5            11620     0              4              2048          10            4              0.2            1.0            100.0          0           0              1              1              plume        /tmp/gym/     /src/data/wind 11620_0daaa07e 0           skip          20             None           0.0001         VRNN         64             0            0            None        1          =BLOB=     10000000       =BLOB=     0.001      =BLOB=     =BLOB=     7              1.0            0          0              1.0       1.0       0              0              uniform      uniform       0.04       0           1.0         1.0            1.0            =BLOB=     1            0              1              1            1              2.0           50             10                            16.0          0.0           1        1              0              1              0              1
# 0fcef4af4850ec ppo      0.0003     1e-05     0.99      0.99      1           0.95           0.005          0.5            0.5            30891     0              4              2048          10            4              0.2            1.0            100.0          0           0              1              1              plume        /tmp/gym/     /src/data/wind 30891_0fcef4af 0           skip          20             None           0.0001         VRNN         64             0            0            None        1          =BLOB=     10000000       =BLOB=     0.01       =BLOB=     =BLOB=     7              1.0            0          0              1.0       1.0       0              0              uniform      uniform       0.04       0           1.0         1.0            1.0            =BLOB=     1            0              1              1            1              2.0           50             10                            0.0           0.0           1        1              0              1              1              1
# 165c3dae9c1f9a ppo      0.0003     1e-05     0.99      0.99      1           0.95           0.005          0.5            0.5            22035     0              4              2048          10            4              0.2            1.0            100.0          0           0              1              1              plume        /tmp/gym/     /src/data/wind 22035_165c3dae 0           skip          20             None           0.0001         VRNN         64             0            0            None        1          =BLOB=     10000000       =BLOB=     0.01       =BLOB=     =BLOB=     7              1.0            0          0              1.0       1.0       0              0              uniform      uniform       0.04       0           1.0         1.0            1.0            =BLOB=     1            0              1              1            1              2.0           50             10                            0.0           0.0           1        1              0              1              1              1
# 17673535431918 ppo      0.0003     1e-05     0.99      0.99      1           0.95           0.005          0.5            0.5            21289     0              4              2048          10            4              0.2            1.0            100.0          0           0              1              1              plume        /tmp/gym/     /src/data/wind 21289_17673535 0           skip          20             None           0.0001         VRNN         64             0            0            None        1          =BLOB=     10000000       =BLOB=     0.001      =BLOB=     =BLOB=     7              1.0            0          0              1.0       1.0       0              0              uniform      uniform       0.04       0           1.0         1.0            1.0            =BLOB=     1            0              1              1            1              2.0           50             10                            0.0           0.0           1        1              0              1              1              1
# 1973a995a6e651 ppo      0.0003     1e-05     0.99      0.99      1           0.95           0.005          0.5            0.5            19213     0              4              2048          10            4              0.2            1.0            100.0          0           0              1              1              plume        /tmp/gym/     /src/data/wind 19213_1973a995 0           skip          20             None           0.0001         VRNN         64             0            0            None        1          =BLOB=     10000000       =BLOB=     0.01       =BLOB=     =BLOB=     7              1.0            0          0              1.0       1.0       0              0              uniform      uniform       0.04       0           1.0         1.0            1.0            =BLOB=     1            0              1              1            1              2.0           50             10                            0.0           0.0           1        1              0              1              1              1
# 1dc2de813baabd ppo      0.0003     1e-05     0.99      0.99      1           0.95           0.005          0.5            0.5            17813     0              4              2048          10            4              0.2            1.0            100.0          0           0              1              1              plume        /tmp/gym/     /src/data/wind 17813_1dc2de81 0           skip          20             None           0.0001         VRNN         64             0            0            None        1          =BLOB=     10000000       =BLOB=     0.01       =BLOB=     =BLOB=     7              1.0            0          0              1.0       1.0       0              0              uniform      uniform       0.04       0           1.0         1.0            1.0            =BLOB=     1            0              1              1            1              2.0           50             10                            0.0           0.0           1        1              0              1              1              1
# 20d62b23ae6b66 ppo      0.0003     1e-05     0.99      0.99      1           0.95           0.005          0.5            0.5            8979      0              4              2048          10            4              0.2            1.0            100.0          0           0              1              1              plume        /tmp/gym/     /src/data/wind 8979_20d62b23a 0           skip          20             None           0.0001         VRNN         64             0            0            None        1          =BLOB=     10000000       =BLOB=     0.001      =BLOB=     =BLOB=     7              1.0            0          0              1.0       1.0       0              0              uniform      uniform       0.04       0           1.0         1.0            1.0            =BLOB=     1            0              1              1            1              2.0           50             10                            0.0           0.0           1        1              0              1              1              1
#    ...
#  (Total: 120)

# %%
# TrainingResult.populate(reserve_jobs=True)
# TrainingResult()
# Out:
# *training_conf hours_elapsed  seed
# +------------+ +------------+ +-------+
# 001935298c849c 11.10512673887 30698
# 00679d6cb443c1 15.25706630123 1312
# 0c7a79ccdebe66 15.71486838267 8250
# 0d59ae1f145ef9 9.420013713969 24371
# 0d71853abf0059 11.59714858220 25256
# 0daaa07e31a5b3 10.65352227456 11620
# 0fcef4af4850ec 14.91671572546 30891
# 165c3dae9c1f9a 10.10292404181 22035
# 17673535431918 6.652255060606 21289
# 1973a995a6e651 16.33019776728 19213
# 1dc2de813baabd 9.398088669114 17813
# 20d62b23ae6b66 13.25782736347 8979
#    ...
#  (Total: 117)

# %%
training_config_hash = [item[0] for item in TrainingResult().fetch()]
training_config = [item[0] for item in TrainingConfig().fetch()]
to_be_done_exp = set(training_config).difference(set(training_config_hash))
print(len(to_be_done_exp))
undone = ['/plume_10057_5e0b837fa56b6a4dffff1a034adcff23.pt',
'/plume_11357_85f2b252e3fb3537cc8b97e7299543d1.pt',
'/plume_13356_edf288d268883f38671e8d8b3c6faa80.pt',
'/plume_19417_4ae9997221924be5c7af5b45ebc2f399.pt',
'/plume_23197_87f2d20ceaa4d4567390aef42c9a18b3.pt',
'/plume_23311_010d39e8723185121880b9cb06092819.pt',
'/plume_31287_f381b0d5c73c6a567dc6a53437118d1b.pt',
'/plume_6337_48886f495fca96cc3bd4e5fae0eff333.pt',
"/plume_8898_d8e5f14b5b73bcc1d45585b57d7f6b8c.pt"]

undone = [exp.split('_')[-1].replace('.pt', '') for exp in undone]
print(len(undone))
print([exp for exp in to_be_done_exp if exp in undone])
to_be_done_exp
for hash in to_be_done_exp:
    print((TrainingConfig() & f'training_config_hash="{hash}"').fetch()['seed'])
# (TrainingConfig() & 'training_config_hash="061f81f6e646a49a94eb2d27c0bf41ef"')

# %% [markdown]
# # insert a hyak-based example 061824

# %%
dict_to_insert = {
 'save_dir': '/src/data/wind_sensing/apparent_wind_visual_feedback/sw_dist_logstep_wind_0.001_train_std_pois_mag_wind/',
#  'outsuffix': '', # to be built by insert 
 'num_processes': 4, # nproc=8 for 4 concurrently agents. 
#  'seed': 2894, # to be sampled when inserting
 'dataset': ['constant_magx5b5', 'switch45x5b5', 'poisson_mag_noisy3x5b5'],
 'num_env_steps': 10000000,
 'qvar': [2.0, 1.0, 0.5], # Variance of init. location; higher = more off-plume initializations. Note this is set to 0 in evalCli 
 'birthx': 0.001, # TODO: verify this is what Toha has
 'diff_max': [0.8, 0.8, 0.8],
 'diff_min': [0.7, 0.65, 0.4],
 'apparent_wind': True,
 'apparent_wind_allo': False,
 'visual_feedback': True,
 'birthx_linear_tc_steps': 7, 
 'birthx_max': 1.0,
 'dryrun': False,
 'algo': 'ppo',
 'lr': 0.0003,
 'eps': 1e-05,
 'alpha': 0.99,
 'gamma': 0.99,
 'use_gae': True,
 'gae_lambda': 0.95,
 'entropy_coef': 0.005,
 'value_loss_coef': 0.5,
 'max_grad_norm': 0.5,
 'cuda_deterministic': False,
 'num_steps': 2048,
 'ppo_epoch': 10,
 'num_mini_batch': 4,
 'clip_param': 0.2,
 'log_interval': 1,
 'save_interval': 100,
 'no_cuda': False,
 'use_proper_time_limits': False,
 'recurrent_policy': True,
 'use_linear_lr_decay': True,
 'env_name': 'plume',
 'log_dir': '/tmp/gym/',
 'dynamic': False,
 'eval_type': 'skip',
 'eval_episodes': 20,
 'eval_interval': None,
 'weight_decay': 0.0001,
 'rnn_type': 'VRNN',
 'hidden_size': 64,
 'betadist': False,
 'stacking': 0,
 'masking': None,
 'stride': 1,
 'curriculum': False,
 'turnx': 1.0,
 'movex': 1.0,
 'auto_movex': False,
 'auto_reward': False,
 'loc_algo': 'uniform',
 'time_algo': 'uniform',
 'env_dt': 0.04,
 'walking': False,
 'radiusx': 1.0,
 'diffusion_min': 1.0,
 'diffusion_max': 1.0,
 'r_shaping': ['step', 'oob'],
 'wind_rel': True,
 'action_feedback': False,
 'squash_action': True,
 'flipping': True,
 'odor_scaling': True,
 'stray_max': 2.0,
 'test_episodes': 50,
 'viz_episodes': 10,
 'model_fname': '',
 'obs_noise': 0.0, # 16deg = 0.28 rad
 'act_noise': 0.0,
 'cuda': True,
 'if_vec_norm': 1,
 'if_train_actor_std': True,
 }

# %%
for i in range(15):
    TrainingConfig.insert1(dict_to_insert)
# Out:
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.
# No seed provided. Generating a new one.

# %%
TrainingConfig().fetch()['outsuffix']
len(TrainingConfig().fetch()['outsuffix'])

# %%
schema.jobs

# %% [markdown]
# # filtering table entries

# %%
TrainingConfig & 'lr < 1'
TrainingConfig().fetch()['save_dir']

# %% [markdown]
# # scaping the table

# %%
TrainingConfig.drop()
